# %% [markdown]
# <a href="https://colab.research.google.com/github/Charmanda11/AulaPraticaVersionamentoAds/blob/master/Imers%C3%A3o_Python_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 2 - Importação

# %%
import pandas as pd

# %%
df_principal = pd.read_excel("/content/Planilha_pura.xlsx", sheet_name="Principal")
df_principal.head(10)
# Out:
#    Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0  USIM5  1/26/2024         9.50          5.20          11.76          2.26
# 1  CMIN3  1/26/2024         6.82          2.40           2.40        -12.11
# 2  PETR3  1/26/2024        41.96          2.19           7.73          7.64
# 3  SUZB3  1/26/2024        52.91          2.04           2.14         -4.89
# 4  CPFE3  1/26/2024        37.10          2.03           2.49         -3.66
# 5  PRIO3  1/26/2024        45.69          1.98           2.42         -0.78
# 6  PETR4  1/26/2024        39.96          1.73           6.47          7.30
# 7  VALE3  1/26/2024        69.50          1.66           2.06         -9.97
# 8  MULT3  1/26/2024        28.19          1.58           2.03         -0.81
# 9  ITUB4  1/26/2024        32.81          1.48          -0.39         -3.36
#
#    Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx    Volume
# 0          2.26         15.97      9.18      9.56  319,16 M
# ...

# %%
df_total_acoes = pd.read_excel("/content/Planilha_pura.xlsx", sheet_name="total_acoes")
df_total_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   2.356656e+08
# 1                      ALOS3   5.326166e+08
# 2                      ALPA4   1.767340e+08
# 3                      ABEV3   4.394246e+09
# 4                      ARZZ3   6.230589e+07
# ..                       ...            ...
# 84                     VBBR3   1.114413e+09
# 85                     WEGE3   1.481593e+09
# 86                     YDUQ3   2.893479e+08
# 87  Quantidade Teórica Total   9.637210e+10
# 88                   Redutor   1.704785e+07
#
# [89 rows x 2 columns]

# %%
df_ticker = pd.read_excel("/content/Planilha_pura.xlsx", sheet_name="Ticker")
df_ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_bard = pd.read_excel("/content/Planilha_pura.xlsx", sheet_name="Bard")
df_bard
# Out:
#           Empresa          Segmento  Idade (anos)
# 0        Usiminas        Siderurgia            66
# 1   CSN Mineração         Mineração            47
# 2       Petrobras    Petróleo e Gás            72
# 3          Suzano  Papel e Celulose            94
# 4    CPFL Energia  Energia Elétrica           111
# ..            ...               ...           ...
# 65         Cyrela  Construção Civil            54
# 66        Embraer           Aviação            53
# 67         Natura        Cosméticos            34
# 68          Assaí        Atacadista            18
# 69             B3  Bolsa de Valores           134
#
# [70 rows x 3 columns]
